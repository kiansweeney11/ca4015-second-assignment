# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import os
from supervised.automl import AutoML

# %%
data = pd.read_excel('data/FrontiersDS.xlsx', sheet_name='Wide')

# %%
data.head()
# Out:
#                                           Unnamed: 0 Unnamed: 1  Unnamed: 2  \
# 0  The data in this sheet was used for the formul...        NaN         NaN
# 1                                                NaN        NaN         NaN
# 2                                            Species     Strain    Samples
# 3                                                 SA       SA_A  SA.A_TSB_A
# 4                                                 SA       SA_A  SA.A_TSB_B
#
#        Unnamed: 3 Unnamed: 4                   Unnamed: 5   Unnamed: 6  \
# 0             NaN        NaN                          NaN          NaN
# 1             NaN        NaN                          NaN          NaN
# 2   Ethyl Acetate    Ethanol  Propanoic acid, ethyl ester  2-Pentanone
# 3          465374    1027715                          NaN      1289650
# 4          193151    1050974                          NaN       504113
#
#   Unnamed: 7              Unnamed: 8       Unnamed: 9  ...  Unnamed: 60  \
# 0        NaN                     NaN              NaN  ...          NaN
# 1        NaN                     NaN              NaN  ...          NaN
# 2     Decane  Methyl Isobutyl Ketone  Amylene hydrate  ...  1-Dodecanol
# 3     800581                  324424            73015  ...          NaN
# 4     294680                  189630                0  ...          NaN
#
#              Unnamed: 61       Unnamed: 62                      Unnamed: 63  \
# 0                    NaN               NaN                              NaN
# 1                    NaN               NaN                              NaN
# 2  Methyl tetradecanoate   2-Pentadecanone  Tetradecanoic acid, ethyl ester
# 3                    NaN               NaN                              NaN
# 4                    NaN               NaN                              NaN
#
#    Unnamed: 64      Unnamed: 65     Unnamed: 66     Unnamed: 67  \
# 0          NaN              NaN             NaN             NaN
# 1          NaN              NaN             NaN             NaN
# 2  Hexadecanal  n-Tridecan-1-ol  1-Tetradecanol  n-Pentadecanol
# 3          NaN              NaN             NaN             NaN
# 4          NaN              NaN             NaN             NaN
#
#       Unnamed: 68 Unnamed: 69
# 0             NaN         NaN
# 1             NaN         NaN
# 2   1-Hexadecanol      Indole
# 3             NaN         NaN
# 4             NaN         NaN
#
# [5 rows x 70 columns]
